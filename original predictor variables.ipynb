# %%
import pandas as pd
import numpy as np
import csv

# %%
df=pd.read_csv("D:/6367 consultant/ACSST1Y2019.S1810_2021-02-14T142158/ACSST1Y2019.S1810_data_with_overlays_2021-02-12T134009.csv")
df.columns = df.iloc[0,:]

# %%
df_state=df.drop([0])
df_state.reset_index()
df_state = df_state.loc[:,df_state.columns.str.contains(".*!!With a disability!!.*")]
df_state = df_state.loc[:,df_state.columns.str.contains(".*Estimate.*")]
col_name = df_state.columns
col_name = col_name.str.replace("Estimate!!With a disability!!","")
col_name = col_name.str.replace("Total civilian noninstitutionalized population!!","")
col_name = col_name.str.replace("RACE AND HISPANIC OR LATINO ORIGIN!!","")
df_state.columns = col_name
df_state.head()
# Out:
# 0 Total civilian noninstitutionalized population SEX!!Male SEX!!Female  \
# 1                                         765018    363930      401088
# 2                                          82900     44738       38162
# 3                                         946481    483196      463285
# 4                                         519094    256349      262745
# 5                                        4124423   1971739     2152684
#
# 0 White alone Black or African American alone  \
# 1      535010                          200257
# 2       52908                            2076
# 3      768830                           41603
# 4      414432                           78977
# 5     2670665                          329249
#
# 0 American Indian and Alaska Native alone Asian alone  \
# 1                                    5974        5816
# 2                                   17785        3232
# 3                                   47127       18640
# ...

# %%
df_county = pd.read_csv("C:/Users/Ming/Downloads/ACSST1Y2019.S1810_data_with_overlays_2021-02-24T165613.csv")
df_county.columns = df_county.iloc[0,:]
df_county = df_county.drop([0])
df_county.reset_index()
df_county = df_county.loc[:,df_county.columns.str.contains(".*!!With a disability!!.*")]
df_county = df_county.loc[:,df_county.columns.str.contains(".*Estimate.*")]
col_name = df_county.columns
col_name = col_name.str.replace("Estimate!!With a disability!!","")
col_name = col_name.str.replace("Total civilian noninstitutionalized population!!","")
col_name = col_name.str.replace("RACE AND HISPANIC OR LATINO ORIGIN!!","")
df_county.columns = col_name
df_county.head()
# Out:
# 0 Total civilian noninstitutionalized population SEX!!Male SEX!!Female  \
# 1                                          31901     15573       16328
# 2                                          22269      9352       12917
# 3                                          14480      6511        7969
# 4                                           7583      4231        3352
# 5                                           9707      4495        5212
#
# 0 White alone Black or African American alone  \
# 1       27623                            2050
# 2       17365                            4119
# 3       13332                               N
# 4        7374                               N
# 5        7245                            2169
#
# 0 American Indian and Alaska Native alone Asian alone  \
# 1                                       N           N
# 2                                       N           N
# 3                                       N           N
# ...

# %%
df_county.shape
# Out:
# (840, 69)
